# %% [markdown]
# <a href="https://colab.research.google.com/github/Lykozy/Transfer-Learning-Metal/blob/main/TfLn_Result_Metal_2_Adam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load_model digunakan untuk meload model sebelumnya yang sudah ditraining (result_metal_1.h5) pada notebook TfLn_Result_Metal_1.ipynb
# yang nantinya akan dilatih lagi dengan data yang dan akan digunakan untuk memprediksi harga metal seperti yang dilakukan pada notebook 
# TfLn_Result_Metal_1.ipynb

from keras.models import load_model
model = load_model('/content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_1/result_metal_1.h5')

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 120, 128)          34816
#
#  sequential_2 (Sequential)   (None, 120, 64)           41472
#
#  bidirectional_2 (Bidirectio  (None, 32)               10368
#  nal)
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 86,817
# Trainable params: 86,369
# Non-trainable params: 448
# _________________________________________________________________
# None

# %% [markdown]
# # Fine Tuning

# %% [markdown]
# Pada notebook ini Fine Tuning akan diterapkan pada model baru menggunakan model 1 yaitu result_metal_1 yang outputnya akan menghasilkan model 2 bernama result_metal_2. Model 2 akan dilatih hanya dengan data Timbal atau Lead, kolom yang akan digunakan adalah X = open dan volume, Y = close.

# %% [markdown]
# ## Instal yang diperlukan

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sb
from tabulate import tabulate
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from math import sqrt

# %%
df = pandas.read_csv('/content/drive/MyDrive/transfer_learning_metal_dataset/Data Historis Timbal Berjangka .csv')

# %% [markdown]
# ## EDA

# %%
df
# Out:
#           date  close   open   high    low  volume
# 0    2019-10-1  2.096  2.130  2.122  2.096   98220
# 1    2019-10-2  2.100  2.095  2.110  2.090   66660
# 2    2019-10-3  2.129  2.108  2.130  2.106   46370
# 3    2019-10-4  2.160  2.149  2.159  2.143   54880
# 4    2019-10-7  2.189  2.181  2.189  2.181   98470
# ..         ...    ...    ...    ...    ...     ...
# 503  2021-9-27  2.163  2.162  2.164  2.162    9560
# 504  2021-9-28  2.169  2.184  2.184  2.184   11200
# 505  2021-9-29  2.140  2.158  2.160  2.158    7540
# 506  2021-9-30  2.093  2.087  2.087  2.078   16970
# 507  2021-10-1  2.141  2.127  2.128  2.126    9940
#
# [508 rows x 6 columns]

# %%
print('Number of missing values : ' + str(df.isna().sum().sum()))
print(df.shape)
# Out:
# Number of missing values : 0
# (508, 6)

# %%
df = df.drop(['date'], axis = 1)

# %%
sb.pairplot(df)

# %%
cor_mat = df.corr ()
fig = plt.figure(figsize = (19,10))
sb.heatmap(cor_mat, annot = True)
plt.show ()

# %%
print (cor_mat['close'].sort_values(ascending = False), '\n')
# Out:
# close     1.000000
# high      0.996801
# low       0.996638
# open      0.992741
# volume   -0.328527
# Name: close, dtype: float64

# %%
column_position = ['open', 'close', 'low', 'high', 'volume']

# %%
plt.figure(figsize = (18, 8))
plt.plot(df['open'])
plt.plot(df['close'])
plt.plot(df['low'])
plt.plot(df['high'])
plt.legend(['open', 'close','low','high'])
plt.xlabel('periode')
plt.ylabel('Harga')
plt.title('Grafik Harga timbal')
plt.savefig('/content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/metal_2_timbal.png')
plt.show()

# %% [markdown]
# * Berhubung open, close, low, high memiliki nilai yang hampir sama, maka hanya 1 yang akan digunakan untuk memberi makan model yaitu close. *

# %%
info = [[col, df[col].count(), df[col].max(), df[col].min()] for col in df.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Maximum', 'Minimum'], tablefmt= 'orgtbl'))
# Out:
# | Feature   |   Count |    Maximum |   Minimum |
# |-----------+---------+------------+-----------|
# | close     |     508 |      2.402 |     1.586 |
# | open      |     508 |      2.398 |     1.602 |
# | high      |     508 |      2.412 |     1.624 |
# | low       |     508 |      2.379 |     1.581 |
# | volume    |     508 | 118340     |  3850     |

# %% [markdown]
# ## Membuat dataset array

# %%
X = np.array(df.drop(['high', 'low', 'close'], axis = 1))
y = np.array(df['close'])

# %%
print(X.shape)
print(y.shape)
# Out:
# (508, 2)
# (508,)

# %% [markdown]
# ## Menskalakan data dengan MinMaxScaler

# %%
X = MinMaxScaler().fit_transform(X)

# %%
t = np.reshape(y, (len(y),1))
t = MinMaxScaler().fit_transform(t)
y = t.reshape(-1)

# %%
print(X.max())
print(X.min())
# Out:
# 1.0
# 0.0

# %%
print(y.max())
print(y.min())
# Out:
# 0.9999999999999998
# 0.0

# %% [markdown]
# ## Membuat array numpy berbasis deret waktu

# %%
length = 120

X_res = []
y_res = []

for i in range(length , len(X)) :
    X_res.append(X[i-length:i])
    y_res.append(y[i])

X_res = np.array(X_res)
y_res = np.array(y_res)

# %%
print(X_res.shape)
print(y_res.shape)
# Out:
# (388, 120, 2)
# (388,)

# %% [markdown]
# ## Fine Tuning

# %%
for i, layer in enumerate(model.layers) :
    if i < 5 :
        layer.trainable = True # Layer akan dilatih lagi (fine tuning), jika tidak dilatih maka menjadi transfer learning

# %% [markdown]
# ## Train test split

# %%
X_train, X_test, y_train, y_test  = train_test_split(X_res, y_res, train_size = 0.8, test_size = 0.2, random_state = 1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (310, 120, 2)
# (310,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (78, 120, 2)
# (78,)

# %% [markdown]
# ## Training Model

# %%
checkp = [tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5', save_best_only = False, verbose = 1), 
          tf.keras.callbacks.CSVLogger('/content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.log', separator=",", append=False)]

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs = 200, 
    batch_size = 64, 
    validation_data = (X_test, y_test), 
    callbacks = [checkp])
# Out:
# Epoch 1/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.0065
# Epoch 1: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 11s 1s/step - loss: 0.0094 - accuracy: 0.0065 - val_loss: 0.0056 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.0065
# Epoch 2: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 430ms/step - loss: 0.0088 - accuracy: 0.0065 - val_loss: 0.0040 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.0065
# Epoch 3: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 445ms/step - loss: 0.0077 - accuracy: 0.0065 - val_loss: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.0065
# Epoch 4: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 435ms/step - loss: 0.0068 - accuracy: 0.0065 - val_loss: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 5/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.0065
# Epoch 5: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 431ms/step - loss: 0.0066 - accuracy: 0.0065 - val_loss: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 6/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.0065
# Epoch 6: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 437ms/step - loss: 0.0053 - accuracy: 0.0065 - val_loss: 0.0041 - val_accuracy: 0.0000e+00
# Epoch 7/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.0065
# Epoch 7: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 433ms/step - loss: 0.0059 - accuracy: 0.0065 - val_loss: 0.0043 - val_accuracy: 0.0000e+00
# Epoch 8/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.0065
# Epoch 8: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 447ms/step - loss: 0.0050 - accuracy: 0.0065 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 9/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.0065
# Epoch 9: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 438ms/step - loss: 0.0056 - accuracy: 0.0065 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 10/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.0065
# Epoch 10: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 445ms/step - loss: 0.0071 - accuracy: 0.0065 - val_loss: 0.0049 - val_accuracy: 0.0000e+00
# Epoch 11/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.0065
# Epoch 11: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 434ms/step - loss: 0.0054 - accuracy: 0.0065 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 12/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.0065
# Epoch 12: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 430ms/step - loss: 0.0068 - accuracy: 0.0065 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# Epoch 13/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.0065
# Epoch 13: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 441ms/step - loss: 0.0046 - accuracy: 0.0065 - val_loss: 0.0041 - val_accuracy: 0.0000e+00
# Epoch 14/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.0065
# Epoch 14: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 441ms/step - loss: 0.0056 - accuracy: 0.0065 - val_loss: 0.0041 - val_accuracy: 0.0000e+00
# Epoch 15/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.0065
# Epoch 15: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 438ms/step - loss: 0.0053 - accuracy: 0.0065 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# Epoch 16/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.0065
# Epoch 16: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 430ms/step - loss: 0.0062 - accuracy: 0.0065 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# Epoch 17/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.0065
# Epoch 17: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 428ms/step - loss: 0.0052 - accuracy: 0.0065 - val_loss: 0.0039 - val_accuracy: 0.0000e+00
# Epoch 18/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.0065
# Epoch 18: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 435ms/step - loss: 0.0047 - accuracy: 0.0065 - val_loss: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 19/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.0065
# Epoch 19: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 433ms/step - loss: 0.
- accuracy: 0.0065 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 176/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.0065
# Epoch 176: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0043 - accuracy: 0.0065 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 177/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.0065
# Epoch 177: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 436ms/step - loss: 0.0031 - accuracy: 0.0065 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 178/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.0065
# Epoch 178: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 434ms/step - loss: 0.0042 - accuracy: 0.0065 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 179/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.0065
# Epoch 179: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 451ms/step - loss: 0.0048 - accuracy: 0.0065 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 180/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.0065
# Epoch 180: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 444ms/step - loss: 0.0033 - accuracy: 0.0065 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 181/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.0065
# Epoch 181: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 450ms/step - loss: 0.0041 - accuracy: 0.0065 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 182/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.0065
# Epoch 182: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 434ms/step - loss: 0.0035 - accuracy: 0.0065 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 183/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.0065
# Epoch 183: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 440ms/step - loss: 0.0038 - accuracy: 0.0065 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 184/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.0065
# Epoch 184: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 435ms/step - loss: 0.0028 - accuracy: 0.0065 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 185/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.0065
# Epoch 185: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 439ms/step - loss: 0.0033 - accuracy: 0.0065 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 186/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.0065
# Epoch 186: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 440ms/step - loss: 0.0029 - accuracy: 0.0065 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 187/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.0065
# Epoch 187: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 438ms/step - loss: 0.0028 - accuracy: 0.0065 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 188/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.0065
# Epoch 188: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 445ms/step - loss: 0.0038 - accuracy: 0.0065 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 189/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.0065
# Epoch 189: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 439ms/step - loss: 0.0036 - accuracy: 0.0065 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 190/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.0065
# Epoch 190: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 450ms/step - loss: 0.0030 - accuracy: 0.0065 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 191/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.0065
# Epoch 191: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 445ms/step - loss: 0.0031 - accuracy: 0.0065 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 192/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.0065
# Epoch 192: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 447ms/step - loss: 0.0030 - accuracy: 0.0065 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 193/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.0065
# Epoch 193: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 445ms/step - loss: 0.0032 - accuracy: 0.0065 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 194/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.0065
# Epoch 194: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 442ms/step - loss: 0.0039 - accuracy: 0.0065 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 195/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.0065
# Epoch 195: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 439ms/step - loss: 0.0040 - accuracy: 0.0065 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 196/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.0065
# Epoch 196: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 439ms/step - loss: 0.0034 - accuracy: 0.0065 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 197/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.0065
# Epoch 197: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 448ms/step - loss: 0.0054 - accuracy: 0.0065 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 198/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.0065
# Epoch 198: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 439ms/step - loss: 0.0037 - accuracy: 0.0065 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 199/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.0065
# Epoch 199: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 443ms/step - loss: 0.0033 - accuracy: 0.0065 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 200/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.0065
# Epoch 200: saving model to /content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 449ms/step - loss: 0.0072 - accuracy: 0.0065 - val_loss: 0.0016 - val_accuracy: 0.0000e+00

# %%
plt.figure(figsize = (16, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train_loss', 'validation_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs Timbal Adam')
plt.savefig('/content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2_loss.png')
plt.show()

# %%
plt.figure(figsize = (16, 8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy', 'validation_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.title('accuracy vs Epochs Timbal Adam')
plt.savefig('/content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2_acc.png')
plt.show()

# %% [markdown]
# ## Prediksi

# %%
model = load_model('/content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2.h5')
pred = model.predict(X_test)

# %%
print(pred.shape)
# Out:
# (78, 1)

# %% [markdown]
# ## Plot the Prediction and Test value

# %%
plt.figure(figsize = (20,8))
plt.plot(y_test)
plt.plot(pred)
plt.xlabel('Periode')
plt.ylabel('Closing Prices')
plt.legend(['testing price','predicted price'])
plt.title('Perbandingan skala harga test dan prediksi close untuk Timbal 78 Periode menggunakan Adam', fontsize = 15)
plt.savefig('/content/drive/MyDrive/TransferLearning/LSTM/Adam/Model_2/result_metal_2_comparison_testingVSpredic_78_periode.png')

# %% [markdown]
# ## Performance Metrics

# %%
print('r2 score : ' + str(r2_score(y_test, pred)))
print('Mean Squared Error (MSE) : ' + str(mean_squared_error(y_test, pred)))
print('Root Mean Squared Error (RMSE) : ' + str(mean_squared_error(y_test, pred, squared=False)))
print('Mean Absolut Error (MAE) : ' + str(mean_absolute_error(y_test, pred)))
print('Mean Absolut Percentage Error (MAPE) : ' + str(mean_absolute_percentage_error(y_test, pred)))
# Out:
# r2 score : 0.9720614873831258
# Mean Squared Error (MSE) : 0.0016207404265946375
# Root Mean Squared Error (RMSE) : 0.04025842056756124
# Mean Absolut Error (MAE) : 0.031862031602871516
# Mean Absolut Percentage Error (MAPE) : 0.0978878976087754
