# %% [markdown]
# <a href="https://colab.research.google.com/github/Lykozy/Transfer-Learning-Metal/blob/main/TfLn_Result_Metal_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pada notebook ini akan dibuat model RNN LSTM yang akan digunakan dalam penerapan transfer learning untuk memprediksi (forecasting) harga tembaga, model bernama result_metal_1. Model akan dilatih dengan data historis Nickel/Nikel. Penerapan Transfer Learning berada di notebook yang berbeda.

# %% [markdown]
# # Pembuatan Model yang akan digunakan dalam penerapan Transfer Learning

# %% [markdown]
# ## Instal yang diperlukan

# %%
import sys
print(sys.version)
# Out:
# 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas
import seaborn
import matplotlib.pyplot as plt
import tensorflow as tf
from tabulate import tabulate
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from math import sqrt

# %%
df = pandas.read_csv('/content/drive/MyDrive/transfer_learning_metal_dataset/Data Historis Nikel Berjangka.csv')

# %% [markdown]
# ## EDA

# %%
df
# Out:
#           date   close    open    high     low  volume
# 0    2019-10-1  17.220  17.250  17.325  17.195  239750
# 1    2019-10-2  17.485  17.525  17.505  17.485  187440
# 2    2019-10-3  17.625  17.630  17.630  17.610  117020
# 3    2019-10-4  17.790  17.825  17.790  17.750   82760
# 4    2019-10-7  17.725  17.800  17.800  17.750  135320
# ..         ...     ...     ...     ...     ...     ...
# 503  2021-9-27  18.946  18.900  18.910  18.870   15600
# 504  2021-9-28  18.564  18.610  18.585  18.600   17460
# 505  2021-9-29  18.342  18.600  18.555  18.555   21270
# 506  2021-9-30  17.936  18.170  18.100  18.100   19540
# 507  2021-10-1  17.971  18.100  18.080  18.100   11970
#
# [508 rows x 6 columns]

# %%
print(df.shape)
# Out:
# (508, 6)

# %%
main_df = df.reset_index(drop = True)

# %%
print('Number of missing values : ' + str(main_df.isna().sum().sum()))
# Out:
# Number of missing values : 0

# %%
main_df = main_df.drop(['date'], axis = 1)

# %%
seaborn.pairplot(main_df)

# %%
cor_mat = main_df.corr ()
fig = plt.figure(figsize = (19,10))
seaborn.heatmap(cor_mat, annot = True)
plt.show ()

# %%
print (cor_mat['close'].sort_values(ascending = False), '\n')
# Out:
# close     1.000000
# low       0.997962
# high      0.997604
# open      0.995332
# volume   -0.415522
# Name: close, dtype: float64

# %%
column_position = ['open', 'close', 'low', 'high', 'volume']

# %%
plt.figure(figsize = (18, 8))
plt.plot(main_df['open'])
plt.plot(main_df['close'])
plt.plot(main_df['low'])
plt.plot(main_df['high'])
plt.legend(['open', 'close','low','high'])
plt.xlabel('periode')
plt.ylabel('Harga')
plt.title('Grafik Harga Nikel')
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_1/Model_metal_1_nikel.png')
plt.show()

# %% [markdown]
# *** Berhubung open, close, low, high memiliki nilai yang hampir sama, maka hanya 1 yang akan digunakan untuk memberi makan model yaitu close. ***

# %%
info = [[col, main_df[col].count(), main_df[col].max(), main_df[col].min()] for col in main_df.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Maximum', 'Minimum'], tablefmt= 'orgtbl'))
# Out:
# | Feature   |   Count |    Maximum |   Minimum |
# |-----------+---------+------------+-----------|
# | close     |     508 |     20.392 |    10.88  |
# | open      |     508 |     20.425 |    11.125 |
# | high      |     508 |     20.35  |    11.28  |
# | low       |     508 |     20.375 |    10.868 |
# | volume    |     508 | 276580     |  7720     |

# %% [markdown]
# ## Membuat Dataset

# %%
X = np.array(main_df.drop(['close', 'low', 'high'], axis = 1))
y = np.array(main_df['close'])

# %%
print(X.shape)
print(y.shape)
# Out:
# (508, 2)
# (508,)

# %% [markdown]
# ## Menskalakan data dengan MinMaxScaler

# %%
print(X[:3])
# Out:
# [[1.7250e+01 2.3975e+05]
#  [1.7525e+01 1.8744e+05]
#  [1.7630e+01 1.1702e+05]]

# %%
X = MinMaxScaler().fit_transform(X)

# %%
print(X[:3])
# Out:
# [[0.65860215 0.86301421]
#  [0.68817204 0.66845198]
#  [0.69946237 0.40653128]]

# %%
print(y.min())
print(y.max())
# Out:
# 10.88
# 20.392

# %%
temp = MinMaxScaler().fit_transform(np.reshape(y, (len(y),1)))
y = temp.reshape(-1)

# %%
print(y.min())
print(y.max())
# Out:
# 0.0
# 1.0

# %%
print(X.min())
print(X.max())
# Out:
# 0.0
# 1.0000000000000002

# %% [markdown]
# ## Membuat array numpy berbasis deret waktu

# %%
length = 120                    
X_res = []
y_res = []

# %%
for i in range(length,len(X)) :
    X_res.append(X[i-length:i])      
    y_res.append(y[i])           

X_res = np.array(X_res)
y_res = np.array(y_res)

# %%
print(X_res.shape)
print(y_res.shape)
# Out:
# (388, 120, 2)
# (388,)

# %%
X_res
# Out:
# array([[[0.65860215, 0.86301421],
#         [0.68817204, 0.66845198],
#         [0.69946237, 0.40653128],
#         ...,
#         [0.08763441, 0.34129287],
#         [0.04569892, 0.50260359],
#         [0.02956989, 0.47653054]],
#
#        [[0.68817204, 0.66845198],
#         [0.69946237, 0.40653128],
#         [0.72043011, 0.27910437],
#         ...,
#         [0.04569892, 0.50260359],
#         [0.02956989, 0.47653054],
#         [0.04032258, 0.31012423]],
#
#        [[0.69946237, 0.40653128],
#         [0.72043011, 0.27910437],
#         [0.71774194, 0.47459644],
#         ...,
#         [0.02956989, 0.47653054],
#         [0.04032258, 0.31012423],
#         [0.        , 0.18693744]],
#
#        ...,
#
#        [[0.61021505, 0.01829949],
#         [0.59602151, 0.0188574 ],
#         [0.54247312, 0.0144313 ],
#         ...,
#         [0.86290323, 0.02670535],
#         [0.83602151, 0.02930893],
#         [0.80483871, 0.03622703]],
#
#        [[0.59602151, 0.0188574 ],
#         [0.54247312, 0.0144313 ],
#         [0.53688172, 0.01182772],
#         ...,
#         [0.83602151, 0.02930893],
#         [0.80483871, 0.03622703],
#         [0.80376344, 0.05039798]],
#
#        [[0.54247312, 0.0144313 ],
#         [0.53688172, 0.01182772],
#         [0.56182796, 0.02599866],
#         ...,
#         [0.80483871, 0.03622703],
#         [0.80376344, 0.05039798],
#         [0.75752688, 0.0439634 ]]])

# %% [markdown]
# ## Train test split

# %%
X_train, X_test, y_train, y_test  = train_test_split(X_res, y_res, train_size = 0.8, test_size = 0.2, random_state = 1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (310, 120, 2)
# (310,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (78, 120, 2)
# (78,)

# %% [markdown]
# ## Pembuatan Model

# %% [markdown]
# Recurrent Neural Network
# Model RNN memiliki memori, yang dapat membantu dalam mempertahankan data masa lalu sehingga prediksi dibuat atas dasar tersebut.
#
# Long Short Term Memory
# Model RNN sederhana memiliki memori jangka pendek dan tidak dapat mempertahankan dependensi yang terjadi jauh sebelum keadaan saat ini. Jadi LSTM (Long Short Term Memory) digunakan untuk mempertahankan dependensi tersebut.

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Bidirectional
from keras.layers import BatchNormalization
from keras.layers import Input
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

# %%
def lstm_layer (hiddenx) :
    
    model = Sequential()
    
    model.add(Bidirectional(LSTM(hiddenx, activation = 'tanh', return_sequences = True)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    return model

# %%
def rnn (hidden1, hidden2, hidden3) :
    
    model = Sequential()
    
    # Input Block
    model.add(Input((length, 2,)))
    
    # LSTM Block
    model.add(lstm_layer(hidden1))
    model.add(lstm_layer(hidden2))
    model.add(Bidirectional(LSTM(hidden3, activation = 'tanh', return_sequences = False)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    # Output Block
    model.add(Dense(1, activation = 'linear'))
    
    model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics='accuracy')
    return model

# %%
model = rnn(64, 32, 16)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 120, 128)          34816
#
#  sequential_2 (Sequential)   (None, 120, 64)           41472
#
#  bidirectional_2 (Bidirectio  (None, 32)               10368
#  nal)
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 86,817
# Trainable params: 86,369
# Non-trainable params: 448
# _________________________________________________________________

# %%
# ModelChekpoint digunakan untuk menyimpan progres training dari suatu model yang nantinya dapat dilanjutkan lagi, baik dengan notebook
# yang berbeda maupun dengan dataset yang berbeda tetapi masih memiliki struktur yang sama dengan data yang digunakan pada model awal

checkp = [tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5', save_best_only = False, verbose = 1), 
          tf.keras.callbacks.CSVLogger('/content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.log', separator=",", append=False)]

# %% [markdown]
# ## Training Model

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs = 200, 
    batch_size = 32, 
    validation_data = (X_test, y_test), 
    callbacks = [checkp])
# Out:
# Epoch 1/200
# 10/10 [==============================] - ETA: 0s - loss: 1.6523 - accuracy: 0.0032
# Epoch 1: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 20s 676ms/step - loss: 1.6523 - accuracy: 0.0032 - val_loss: 0.2848 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 10/10 [==============================] - ETA: 0s - loss: 1.1646 - accuracy: 0.0065
# Epoch 2: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 330ms/step - loss: 1.1646 - accuracy: 0.0065 - val_loss: 0.2156 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 10/10 [==============================] - ETA: 0s - loss: 0.8166 - accuracy: 0.0032
# Epoch 3: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 336ms/step - loss: 0.8166 - accuracy: 0.0032 - val_loss: 0.1773 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 10/10 [==============================] - ETA: 0s - loss: 0.7921 - accuracy: 0.0065
# Epoch 4: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 321ms/step - loss: 0.7921 - accuracy: 0.0065 - val_loss: 0.1338 - val_accuracy: 0.0000e+00
# Epoch 5/200
# 10/10 [==============================] - ETA: 0s - loss: 0.7698 - accuracy: 0.0065
# Epoch 5: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 337ms/step - loss: 0.7698 - accuracy: 0.0065 - val_loss: 0.1053 - val_accuracy: 0.0000e+00
# Epoch 6/200
# 10/10 [==============================] - ETA: 0s - loss: 0.6240 - accuracy: 0.0065
# Epoch 6: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 330ms/step - loss: 0.6240 - accuracy: 0.0065 - val_loss: 0.0868 - val_accuracy: 0.0000e+00
# Epoch 7/200
# 10/10 [==============================] - ETA: 0s - loss: 0.4961 - accuracy: 0.0032
# Epoch 7: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 329ms/step - loss: 0.4961 - accuracy: 0.0032 - val_loss: 0.0729 - val_accuracy: 0.0000e+00
# Epoch 8/200
# 10/10 [==============================] - ETA: 0s - loss: 0.4909 - accuracy: 0.0032
# Epoch 8: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 342ms/step - loss: 0.4909 - accuracy: 0.0032 - val_loss: 0.0608 - val_accuracy: 0.0000e+00
# Epoch 9/200
# 10/10 [==============================] - ETA: 0s - loss: 0.5074 - accuracy: 0.0032
# Epoch 9: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 5s 563ms/step - loss: 0.5074 - accuracy: 0.0032 - val_loss: 0.0564 - val_accuracy: 0.0000e+00
# Epoch 10/200
# 10/10 [==============================] - ETA: 0s - loss: 0.4375 - accuracy: 0.0065
# Epoch 10: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 352ms/step - loss: 0.4375 - accuracy: 0.0065 - val_loss: 0.0530 - val_accuracy: 0.0000e+00
# Epoch 11/200
# 10/10 [==============================] - ETA: 0s - loss: 0.4140 - accuracy: 0.0065
# Epoch 11: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 330ms/step - loss: 0.4140 - accuracy: 0.0065 - val_loss: 0.0473 - val_accuracy: 0.0000e+00
# Epoch 12/200
# 10/10 [==============================] - ETA: 0s - loss: 0.4492 - accuracy: 0.0032
# Epoch 12: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 331ms/step - loss: 0.4492 - accuracy: 0.0032 - val_loss: 0.0492 - val_accuracy: 0.0000e+00
# Epoch 13/200
# 10/10 [==============================] - ETA: 0s - loss: 0.4062 - accuracy: 0.0065
# Epoch 13: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 348ms/step - loss: 0.4062 - accuracy: 0.0065 - val_loss: 0.0518 - val_accuracy: 0.0000e+00
# Epoch 14/200
# 10/10 [==============================] - ETA: 0s - loss: 0.4226 - accuracy: 0.0032
# Epoch 14: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 340ms/step - loss: 0.4226 - accuracy: 0.0032 - val_loss: 0.0556 - val_accuracy: 0.0000e+00
# Epoch 15/200
# 10/10 [==============================] - ETA: 0s - loss: 0.4114 - accuracy: 0.0032
# Epoch 15: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 338ms/step - loss: 0.4114 - accuracy: 0.0032 - val_loss: 0.0537 - val_accuracy: 0.0000e+00
# Epoch 16/200
# 10/10 [==============================] - ETA: 0s - loss: 0.4735 - accuracy: 0.0032
# Epoch 16: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 327ms/step - loss: 0.4735 - accuracy: 0.0032 - val_loss: 0.0714 - val_accuracy: 0.0000e+00
# Epoch 17/200
# 10/10 [==============================] - ETA: 0s - loss: 0.3704 - accuracy: 0.0000e+00
# Epoch 17: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 332ms/step - loss: 0.3704 - accuracy: 0.0000e+00 - val_loss: 0.0765 - val_accuracy: 0.0000e+00
# Epoch 18/200
# 10/10 [==============================] - ETA: 0s - loss: 0.3020 - accuracy: 0.0065
# Epoch 18: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 338ms/step - loss: 0.3020 - accuracy: 0.0065 - val_loss: 0.0805 - val_accuracy: 0.0000e+00
# Epoch 19/200
# 10/10 [==============================] - ETA: 0s - loss: 0.3458 - accuracy: 0.0032
# Epoch 19: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 353ms/step - loss: 0.3458 - accuracy: 0.0032 - val_loss: 0.0765 - val_accuracy: 0.0000e+00
# Epoch 20/200
# 10/10 [==============================] - ETA: 0s - loss: 0.3510 - accuracy: 0.0065
# Epoch 20: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 333ms/step - loss: 0.3510 - accuracy: 0.0065 - val_loss: 0.0787 - val_accuracy: 0.0000e+00
# Epoch 21/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2897 - accuracy: 0.0032
# Epoch 21: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 418ms/step - loss: 0.2897 - accuracy: 0.0032 - val_loss: 0.0843 - val_accuracy: 0.0000e+00
# Epoch 22/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2966 - accuracy: 0.0032
# Epoch 22: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 355ms/step - loss: 0.2966 - accuracy: 0.0032 - val_loss: 0.0820 - val_accuracy: 0.0000e+00
# Epoch 23/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2800 - accuracy: 0.0065
# Epoch 23: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 351ms/step - loss: 0.2800 - accuracy: 0.0065 - val_loss: 0.0933 - val_accuracy: 0.0000e+00
# Epoch 24/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.0065
# Epoch 24: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 356ms/step - loss: 0.2887 - accuracy: 0.0065 - val_loss: 0.0941 - val_accuracy: 0.0000e+00
# Epoch 25/200
# 10/10 [==============================] - ETA: 0s - loss: 0.3041 - accuracy: 0.0032
# Epoch 25: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 370ms/step - loss: 0.3041 - accuracy: 0.0032 - val_loss: 0.0900 - val_accuracy: 0.0000e+00
# Epoch 26/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.0065
# Epoch 26: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 350ms/step - loss: 0.2466 - accuracy: 0.0065 - val_loss: 0.0948 - val_accuracy: 0.0000e+00
# Epoch 27/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.0065
# Epoch 27: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 335ms/step - loss: 0.2641 - accuracy: 0.0065 - val_loss: 0.0968 - val_accuracy: 0.0000e+00
# Epoch 28/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.0032
# Epoch 28: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 354ms/step - loss: 0.2198 - accuracy: 0.0032 - val_loss: 0.0882 - val_accuracy: 0.0000e+00
# Epoch 29/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2638 - accuracy: 0.0065
# Epoch 29: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 348ms/step - loss: 0.2638 - accuracy: 0.0065 - val_loss: 0.0799 - val_accuracy: 0.0000e+00
# Epoch 30/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 0.0032
# Epoch 30: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 345ms/step - loss: 0.2283 - accuracy: 0.0032 - val_loss: 0.0814 - val_accuracy: 0.0000e+00
# Epoch 31/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.0065
# Epoch 31: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 331ms/step - loss: 0.2261 - accuracy: 0.0065 - val_loss: 0.0858 - val_accuracy: 0.0000e+00
# Epoch 32/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2130 - accuracy: 0.0065
# Epoch 32: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 341ms/step - loss: 0.2130 - accuracy: 0.0065 - val_loss: 0.0832 - val_accuracy: 0.0000e+00
# Epoch 33/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2215 - accuracy: 0.0032
# Epoch 33: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 324ms/step - loss: 0.2215 - accuracy: 0.0032 - val_loss: 0.0745 - val_accuracy: 0.0000e+00
# Epoch 34/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.0065
# Epoch 34: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 336ms/step - loss: 0.2157 - accuracy: 0.0065 - val_loss: 0.0665 - val_accuracy: 0.0000e+00
# Epoch 35/200
# 10/10 [==============================] - ETA: 0s - loss: 0.2349 - accuracy: 0.0032
# Epoch 35: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 336ms/step - loss: 0.2349 - accuracy: 0.0032 - val_loss: 0.0513 - val_accuracy: 0.0000e+00
# Epoch 36/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.0032
# Epoch 36: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 352ms/step - loss: 0.1772 - accuracy: 0.0032 - val_loss: 0.0449 - val_accuracy: 0.0000e+00
# Epoch 37/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.0032
# Epoch 37: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 370ms/step - loss: 0.1877 - accuracy: 0.0032 - val_loss: 0.0478 - val_accuracy: 0.0000e+00
# Epoch 38/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 0.0065
# Epoch 38: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 335ms/step - loss: 0.1961 - accuracy: 0.0065 - val_loss: 0.0476 - val_accuracy: 0.0000e+00
# Epoch 39/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.0032
# Epoch 39: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 353ms/step - loss: 0.1505 - accuracy: 0.0032 - val_loss: 0.0411 - val_accuracy: 0.0000e+00
# Epoch 40/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.0065
# Epoch 40: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 349ms/step - loss: 0.1700 - accuracy: 0.0065 - val_loss: 0.0370 - val_accuracy: 0.0000e+00
# Epoch 41/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.0032
# Epoch 41: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 337ms/step - loss: 0.1592 - accuracy: 0.0032 - val_loss: 0.0229 - val_accuracy: 0.0000e+00
# Epoch 42/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.0065
# Epoch 42: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 341ms/step - loss: 0.1525 - accuracy: 0.0065 - val_loss: 0.0163 - val_accuracy: 0.0000e+00
# Epoch 43/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.0065
# Epoch 43: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 378ms/step - loss: 0.1490 - accuracy: 0.0065 - val_loss: 0.0159 - val_accuracy: 0.0000e+00
# Epoch 44/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.0032
# Epoch 44: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 342ms/step - loss: 0.1570 - accuracy: 0.0032 - val_loss: 0.0174 - val_accuracy: 0.0000e+00
# Epoch 45/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.0065
# Epoch 45: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 349ms/step - loss: 0.1307 - accuracy: 0.0065 - val_loss: 0.0158 - val_accuracy: 0.0000e+00
# Epoch 46/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1492 - accuracy: 0.0065
# Epoch 46: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 363ms/step - loss: 0.1492 - accuracy: 0.0065 - val_loss: 0.0181 - val_accuracy: 0.0000e+00
# Epoch 47/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.0065
# Epoch 47: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 341ms/step - loss: 0.1313 - accuracy: 0.0065 - val_loss: 0.0210 - val_accuracy: 0.0000e+00
# Epoch 48/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.0065
# Epoch 48: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 336ms/step - loss: 0.1358 - accuracy: 0.0065 - val_loss: 0.0119 - val_accuracy: 0.0000e+00
# Epoch 49/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.0065
# Epoch 49: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 355ms/step - loss: 0.1145 - accuracy: 0.0065 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 50/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.0065
# Epoch 50: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 343ms/step - loss: 0.1230 - accuracy: 0.0065 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 51/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.0065
# Epoch 51: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 329ms/step - loss: 0.1300 - accuracy: 0.0065 - val_loss: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 52/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.0065
# Epoch 52: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 445ms/step - loss: 0.1231 - accuracy: 0.0065 - val_loss: 0.0081 - val_accuracy: 0.0000e+00
# Epoch 53/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1113 - accuracy: 0.0032
# Epoch 53: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 335ms/step - loss: 0.1113 - accuracy: 0.0032 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 54/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.0065
# Epoch 54: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 348ms/step - loss: 0.1211 - accuracy: 0.0065 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 55/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.0065
# Epoch 55: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 343ms/step - loss: 0.1174 - accuracy: 0.0065 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 56/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.0065
# Epoch 56: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 331ms/step - loss: 0.1169 - accuracy: 0.0065 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 57/200
# 10/10 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0
- accuracy: 0.0065 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 176/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.0065
# Epoch 176: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 332ms/step - loss: 0.0098 - accuracy: 0.0065 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 177/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.0065
# Epoch 177: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 335ms/step - loss: 0.0077 - accuracy: 0.0065 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 178/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.0065
# Epoch 178: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 343ms/step - loss: 0.0111 - accuracy: 0.0065 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 179/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.0065
# Epoch 179: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 342ms/step - loss: 0.0088 - accuracy: 0.0065 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 180/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.0065
# Epoch 180: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 347ms/step - loss: 0.0067 - accuracy: 0.0065 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 181/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.0065
# Epoch 181: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 361ms/step - loss: 0.0087 - accuracy: 0.0065 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 182/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.0065
# Epoch 182: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 346ms/step - loss: 0.0080 - accuracy: 0.0065 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 183/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.0065
# Epoch 183: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 335ms/step - loss: 0.0080 - accuracy: 0.0065 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 184/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.0065
# Epoch 184: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 353ms/step - loss: 0.0067 - accuracy: 0.0065 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 185/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.0065
# Epoch 185: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 338ms/step - loss: 0.0091 - accuracy: 0.0065 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 186/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.0065
# Epoch 186: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 331ms/step - loss: 0.0085 - accuracy: 0.0065 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 187/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.0065
# Epoch 187: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 344ms/step - loss: 0.0083 - accuracy: 0.0065 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 188/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.0065
# Epoch 188: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 330ms/step - loss: 0.0086 - accuracy: 0.0065 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 189/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.0065
# Epoch 189: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 333ms/step - loss: 0.0073 - accuracy: 0.0065 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 190/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.0065
# Epoch 190: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 333ms/step - loss: 0.0082 - accuracy: 0.0065 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 191/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.0065
# Epoch 191: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 327ms/step - loss: 0.0088 - accuracy: 0.0065 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 192/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.0065
# Epoch 192: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 333ms/step - loss: 0.0074 - accuracy: 0.0065 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 193/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.0065
# Epoch 193: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 330ms/step - loss: 0.0065 - accuracy: 0.0065 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 194/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.0065
# Epoch 194: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 370ms/step - loss: 0.0085 - accuracy: 0.0065 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 195/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.0065
# Epoch 195: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 4s 356ms/step - loss: 0.0065 - accuracy: 0.0065 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 196/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.0065
# Epoch 196: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 348ms/step - loss: 0.0080 - accuracy: 0.0065 - val_loss: 0.0030 - val_accuracy: 0.0000e+00
# Epoch 197/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.0065
# Epoch 197: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 342ms/step - loss: 0.0076 - accuracy: 0.0065 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 198/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.0065
# Epoch 198: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 339ms/step - loss: 0.0073 - accuracy: 0.0065 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 199/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.0065
# Epoch 199: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 354ms/step - loss: 0.0104 - accuracy: 0.0065 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 200/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.0065
# Epoch 200: saving model to /content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5
# 10/10 [==============================] - 3s 343ms/step - loss: 0.0058 - accuracy: 0.0065 - val_loss: 0.0024 - val_accuracy: 0.0000e+00

# %%
history.history??

# %%
plt.figure(figsize = (16, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train_loss', 'validation_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs Nikel')
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_1/result_metal_1_loss.png')
plt.show()

# %%
plt.figure(figsize = (16, 8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy', 'validation_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.title('accuracy vs Epochs Nikel')
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_1/result_metal_1_acc.png')
plt.show()

# %% [markdown]
# ## Prediksi

# %%
model_pred = load_model('/content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5')

# %%
pred = model_pred.predict(X_test)

# %%
print(pred.shape)
# Out:
# (78, 1)

# %% [markdown]
# ## Plot the Prediction and Test value

# %%
plt.figure(figsize = (20,8))
plt.plot(y_test)
plt.plot(pred)
plt.xlabel('Periode')
plt.ylabel('skala')
plt.legend(['testing price','predicted price'])
plt.title('Perbandingan skala harga test dan prediksi close untuk Nikel 78 Periode', fontsize = 15)
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_1/result_metal_1_comparison_testingVSpredic_78_periode.png')
# Out:
# Text(0.5, 1.0, 'Perbandingan skala harga test dan prediksi close untuk Nikel 78 Periode')

# %% [markdown]
# ## Performance Metrics

# %%
print('r2 score : ' + str(r2_score(y_test, pred)))
print('Mean Squared Error (MSE) : ' + str(mean_squared_error(y_test, pred)))
print('Root Mean Squared Error (RMSE) : ' + str(mean_squared_error(y_test, pred, squared=False)))
print('Mean Absolut Error (MAE) : ' + str(mean_absolute_error(y_test, pred)))
print('Mean Absolut Percentage Error (MAPE) : ' + str(mean_absolute_percentage_error(y_test, pred)))
# Out:
# r2 score : 0.9617104712531996
# Mean Squared Error (MSE) : 0.002395676685460298
# Root Mean Squared Error (RMSE) : 0.048945650322171616
# Mean Absolut Error (MAE) : 0.03635238281445282
# Mean Absolut Percentage Error (MAPE) : 0.10179673880331515
