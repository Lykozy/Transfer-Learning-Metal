# %% [markdown]
# <a href="https://colab.research.google.com/github/Lykozy/Transfer-Learning-Metal/blob/main/TfLn_Result_Metal_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load_model digunakan untuk meload model sebelumnya yang sudah ditraining (result_metal_1.h5) pada notebook TfLn_Result_Metal_1.ipynb
# yang nantinya akan dilatih lagi dengan data yang dan akan digunakan untuk memprediksi harga metal seperti yang dilakukan pada notebook 
# TfLn_Result_Metal_1.ipynb

from keras.models import load_model
model = load_model('/content/drive/MyDrive/TransferLearning/Model_1/result_metal_1.h5')

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential_1 (Sequential)   (None, 120, 128)          34816
#
#  sequential_2 (Sequential)   (None, 120, 64)           41472
#
#  bidirectional_2 (Bidirectio  (None, 32)               10368
#  nal)
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# ...
# Total params: 86,817
# Trainable params: 86,369
# Non-trainable params: 448
# _________________________________________________________________
# None

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# Pada notebook ini Transfer Learning akan diterapkan pada model baru menggunakan model 1 yaitu result_metal_1 yang outputnya akan menghasilkan model 2 bernama result_metal_2. Model 2 akan dilatih hanya dengan data Timbal atau Lead, kolom yang akan digunakan adalah X = open dan volume, Y = close.

# %% [markdown]
# ## Instal yang diperlukan

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sb
from tabulate import tabulate
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from math import sqrt

# %%
df = pandas.read_csv('/content/drive/MyDrive/transfer_learning_metal_dataset/Data Historis Timbal Berjangka .csv')

# %% [markdown]
# ## EDA

# %%
df
# Out:
#           date  close   open   high    low  volume
# 0    2019-10-1  2.096  2.130  2.122  2.096   98220
# 1    2019-10-2  2.100  2.095  2.110  2.090   66660
# 2    2019-10-3  2.129  2.108  2.130  2.106   46370
# 3    2019-10-4  2.160  2.149  2.159  2.143   54880
# 4    2019-10-7  2.189  2.181  2.189  2.181   98470
# ..         ...    ...    ...    ...    ...     ...
# 503  2021-9-27  2.163  2.162  2.164  2.162    9560
# 504  2021-9-28  2.169  2.184  2.184  2.184   11200
# 505  2021-9-29  2.140  2.158  2.160  2.158    7540
# 506  2021-9-30  2.093  2.087  2.087  2.078   16970
# 507  2021-10-1  2.141  2.127  2.128  2.126    9940
#
# [508 rows x 6 columns]

# %%
print('Number of missing values : ' + str(df.isna().sum().sum()))
print(df.shape)
# Out:
# Number of missing values : 0
# (508, 6)

# %%
df = df.drop(['date'], axis = 1)

# %%
sb.pairplot(df)

# %%
cor_mat = df.corr ()
fig = plt.figure(figsize = (19,10))
sb.heatmap(cor_mat, annot = True)
plt.show ()

# %%
print (cor_mat['close'].sort_values(ascending = False), '\n')
# Out:
# close     1.000000
# high      0.996801
# low       0.996638
# open      0.992741
# volume   -0.328527
# Name: close, dtype: float64

# %%
column_position = ['open', 'close', 'low', 'high', 'volume']

# %%
plt.figure(figsize = (18, 8))
plt.plot(df['open'])
plt.plot(df['close'])
plt.plot(df['low'])
plt.plot(df['high'])
plt.legend(['open', 'close','low','high'])
plt.xlabel('periode')
plt.ylabel('Harga')
plt.title('Grafik Harga timbal')
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_2/metal_1_timbal.png')
plt.show()

# %% [markdown]
# * Berhubung open, close, low, high memiliki nilai yang hampir sama, maka hanya 1 yang akan digunakan untuk memberi makan model yaitu close. *

# %%
info = [[col, df[col].count(), df[col].max(), df[col].min()] for col in df.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Maximum', 'Minimum'], tablefmt= 'orgtbl'))
# Out:
# | Feature   |   Count |    Maximum |   Minimum |
# |-----------+---------+------------+-----------|
# | close     |     508 |      2.402 |     1.586 |
# | open      |     508 |      2.398 |     1.602 |
# | high      |     508 |      2.412 |     1.624 |
# | low       |     508 |      2.379 |     1.581 |
# | volume    |     508 | 118340     |  3850     |

# %% [markdown]
# ## Membuat dataset array

# %%
X = np.array(df.drop(['high', 'low', 'close'], axis = 1))
y = np.array(df['close'])

# %%
print(X.shape)
print(y.shape)
# Out:
# (508, 2)
# (508,)

# %% [markdown]
# ## Menskalakan data dengan MinMaxScaler

# %%
X = MinMaxScaler().fit_transform(X)

# %%
t = np.reshape(y, (len(y),1))
t = MinMaxScaler().fit_transform(t)
y = t.reshape(-1)

# %%
print(X.max())
print(X.min())
# Out:
# 1.0
# 0.0

# %%
print(y.max())
print(y.min())
# Out:
# 0.9999999999999998
# 0.0

# %% [markdown]
# ## Membuat array numpy berbasis deret waktu

# %%
length = 120

X_res = []
y_res = []

for i in range(length , len(X)) :
    X_res.append(X[i-length:i])
    y_res.append(y[i])

X_res = np.array(X_res)
y_res = np.array(y_res)

# %%
print(X_res.shape)
print(y_res.shape)
# Out:
# (388, 120, 2)
# (388,)

# %% [markdown]
# ## Prediksi Timbal

# %%
for i, layer in enumerate(model.layers) :
    if i < 5 :
        layer.trainable = True # Layer akan dilatih lagi (fine tuning), jika tidak dilatih maka menjadi transfer learning

# %% [markdown]
# ## Train test split

# %%
X_train, X_test, y_train, y_test  = train_test_split(X_res, y_res, train_size = 0.8, test_size = 0.2, random_state = 1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (310, 120, 2)
# (310,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (78, 120, 2)
# (78,)

# %% [markdown]
# ## Training Model

# %%
checkp = [tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/TransferLearning/Model_2/result_metal_2.h5', save_best_only = False, verbose = 1), 
          tf.keras.callbacks.CSVLogger('/content/drive/MyDrive/TransferLearning/Model_2/result_metal_2.log', separator=",", append=False)]

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs = 200, 
    batch_size = 64, 
    validation_data = (X_test, y_test), 
    callbacks = [checkp])
# Out:
# Epoch 1/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.0065
# Epoch 1: saving model to /content/drive/MyDrive/TransferLearning/Model_2/result_metal_2.h5
# 5/5 [==============================] - 13s 1s/step - loss: 0.0115 - accuracy: 0.0065 - val_loss: 0.0058 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.0065
# Epoch 2: saving model to /content/drive/MyDrive/TransferLearning/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 474ms/step - loss: 0.0102 - accuracy: 0.0065 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.0065
# Epoch 3: saving model to /content/drive/MyDrive/TransferLearning/Model_2/result_metal_2.h5
# 5/5 [==============================] - 2s 480ms/step - loss: 0.0084 - accuracy: 0.0065 - val_loss: 0.0043 - val_accuracy: 0.0000e+00
# Epoch 4/200
# ...

# %%
plt.figure(figsize = (16, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train_loss', 'validation_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs Timbal')
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_2/result_metal_2_loss.png')
plt.show()

# %%
plt.figure(figsize = (16, 8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy', 'validation_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.title('accuracy vs Epochs Timbal')
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_2/result_metal_2_acc.png')
plt.show()

# %% [markdown]
# ## Prediksi

# %%
model = load_model('/content/drive/MyDrive/TransferLearning/Model_2/result_metal_2.h5')
pred = model.predict(X_test)

# %%
print(pred.shape)
# Out:
# (78, 1)

# %% [markdown]
# ## Plot the Prediction and Test value

# %%
plt.figure(figsize = (20,8))
plt.plot(y_test)
plt.plot(pred)
plt.xlabel('Periode')
plt.ylabel('Closing Prices')
plt.legend(['testing price','predicted price'])
plt.title('Perbandingan skala harga test dan prediksi close untuk Timbal 78 Periode', fontsize = 15)
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_2/result_metal_2_comparison_testingVSpredic_78_periode.png')

# %% [markdown]
# ## Performance Metrics

# %%
print('r2 score : ' + str(r2_score(y_test, pred)))
print('Mean Squared Error (MSE) : ' + str(mean_squared_error(y_test, pred)))
print('Root Mean Squared Error (RMSE) : ' + str(mean_squared_error(y_test, pred, squared=False)))
print('Mean Absolut Error (MAE) : ' + str(mean_absolute_error(y_test, pred)))
print('Mean Absolut Percentage Error (MAPE) : ' + str(mean_absolute_percentage_error(y_test, pred)))
# Out:
# r2 score : 0.9698484380390172
# Mean Squared Error (MSE) : 0.0017491215822857643
# Root Mean Squared Error (RMSE) : 0.04182250090902939
# Mean Absolut Error (MAE) : 0.03249108778240697
# Mean Absolut Percentage Error (MAPE) : 0.09673162229602833
