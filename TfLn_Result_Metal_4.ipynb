# %% [markdown]
# <a href="https://colab.research.google.com/github/Lykozy/Transfer-Learning-Metal/blob/main/TfLn_Result_Metal_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.models import load_model
model = load_model('/content/drive/MyDrive/TransferLearning/Model_3/result_metal_3.h5')

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential_1 (Sequential)   (None, 120, 128)          34816
#
#  sequential_2 (Sequential)   (None, 120, 64)           41472
#
#  bidirectional_2 (Bidirectio  (None, 32)               10368
#  nal)
#
#  batch_normalization_2 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# ...
# Total params: 86,817
# Trainable params: 86,369
# Non-trainable params: 448
# _________________________________________________________________
# None

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# Pada notebook ini Transfer Learning akan diterapkan pada model baru menggunakan model 1 yaitu result_metal_1 yang outputnya akan menghasilkan model 2 bernama result_metal_2. Model 2 akan dilatih hanya dengan data Timbal atau Lead, kolom yang akan digunakan adalah X = open dan volume, Y = close.

# %% [markdown]
# ## Instal yang diperlukan

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sb
from tabulate import tabulate
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from math import sqrt

# %%
df = pandas.read_csv('/content/drive/MyDrive/transfer_learning_metal_dataset/Data Historis Tembaga Berjangka.csv')

# %% [markdown]
# ## EDA

# %%
df
# Out:
#           date  close   open   high    low  volume
# 0    2019-10-1  5.686  5.640  5.686  5.601  257720
# 1    2019-10-2  5.678  5.662  5.702  5.662  202320
# 2    2019-10-3  5.662  5.657  5.665  5.655  191830
# 3    2019-10-4  5.643  5.640  5.643  5.634  159590
# 4    2019-10-7  5.722  5.669  5.722  5.669  182430
# ..         ...    ...    ...    ...    ...     ...
# 503  2021-9-27  9.362  9.335  9.328  9.328   31950
# 504  2021-9-28  9.269  9.275  9.263  9.260   32070
# 505  2021-9-29  9.155  9.220  9.215  9.215   29880
# 506  2021-9-30  8.937  9.030  9.025  9.021   38370
# 507  2021-10-1  9.128  9.100  9.099  9.100   33670
#
# [508 rows x 6 columns]

# %%
print('Number of missing values : ' + str(df.isna().sum().sum()))
print(df.shape)
# Out:
# Number of missing values : 0
# (508, 6)

# %%
df = df.drop(['date'], axis = 1)

# %%
sb.pairplot(df)

# %%
cor_mat = df.corr ()
fig = plt.figure(figsize = (19,10))
sb.heatmap(cor_mat, annot = True)
plt.show ()

# %%
print (cor_mat['close'].sort_values(ascending = False), '\n')
# Out:
# close     1.000000
# low       0.999361
# high      0.999333
# open      0.998544
# volume   -0.680903
# Name: close, dtype: float64

# %%
column_position = ['open', 'close', 'low', 'high', 'volume']

# %%
plt.figure(figsize = (18, 8))
plt.plot(df['open'])
plt.plot(df['close'])
plt.plot(df['low'])
plt.plot(df['high'])
plt.legend(['open', 'close','low','high'])
plt.xlabel('periode')
plt.ylabel('Harga')
plt.title('Grafik Harga tembaga')
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_4/metal_4_tembaga.png')
plt.show()

# %% [markdown]
# * Berhubung open, close, low, high memiliki nilai yang hampir sama, maka hanya 1 yang akan digunakan untuk memberi makan model yaitu close. *

# %%
info = [[col, df[col].count(), df[col].max(), df[col].min()] for col in df.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Maximum', 'Minimum'], tablefmt= 'orgtbl'))
# Out:
# | Feature   |   Count |    Maximum |   Minimum |
# |-----------+---------+------------+-----------|
# | close     |     508 |     10.46  |     4.63  |
# | open      |     508 |     10.557 |     4.642 |
# | high      |     508 |     10.746 |     4.676 |
# | low       |     508 |     10.386 |     4.463 |
# | volume    |     508 | 268450     | 13820     |

# %% [markdown]
# ## Membuat dataset array

# %%
X = np.array(df.drop(['high', 'low', 'close'], axis = 1))
y = np.array(df['close'])

# %%
print(X.shape)
print(y.shape)
# Out:
# (508, 2)
# (508,)

# %% [markdown]
# ## Menskalakan data dengan MinMaxScaler

# %%
X = MinMaxScaler().fit_transform(X)

# %%
t = np.reshape(y, (len(y),1))
t = MinMaxScaler().fit_transform(t)
y = t.reshape(-1)

# %%
print(X.max())
print(X.min())
# Out:
# 1.0
# 0.0

# %%
print(y.max())
print(y.min())
# Out:
# 0.9999999999999999
# 0.0

# %% [markdown]
# ## Membuat array numpy berbasis deret waktu

# %%
length = 120

X_res = []
y_res = []

for i in range(length , len(X)) :
    X_res.append(X[i-length:i])
    y_res.append(y[i])

X_res = np.array(X_res)
y_res = np.array(y_res)

# %%
print(X_res.shape)
print(y_res.shape)
# Out:
# (388, 120, 2)
# (388,)

# %% [markdown]
# ## Prediksi Aluminum

# %%
for i, layer in enumerate(model.layers) :
    if i < 5 :
        layer.trainable = False # Layer akan dilatih lagi

# %% [markdown]
# ## Train test split

# %%
X_train, X_test, y_train, y_test  = train_test_split(X_res, y_res, train_size = 0.75, test_size = 0.25, random_state = 1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (291, 120, 2)
# (291,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (97, 120, 2)
# (97,)

# %% [markdown]
# ## Training Model

# %%
checkp = [tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/TransferLearning/Model_4/result_metal_4.h5', save_best_only = False,  verbose = 1), 
          tf.keras.callbacks.CSVLogger('/content/drive/MyDrive/TransferLearning/Model_4/result_metal_4.log', separator=",", append=False)]

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs = 100, 
    batch_size = 64, 
    validation_data = (X_test, y_test), 
    callbacks = [checkp])
# Out:
# Epoch 1/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.0069
# Epoch 1: saving model to /content/drive/MyDrive/TransferLearning/Model_4/result_metal_4.h5
# 5/5 [==============================] - 12s 1s/step - loss: 0.0193 - accuracy: 0.0069 - val_loss: 0.0114 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.0069
# Epoch 2: saving model to /content/drive/MyDrive/TransferLearning/Model_4/result_metal_4.h5
# 5/5 [==============================] - 2s 467ms/step - loss: 0.0154 - accuracy: 0.0069 - val_loss: 0.0126 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 5/5 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.0069
# Epoch 3: saving model to /content/drive/MyDrive/TransferLearning/Model_4/result_metal_4.h5
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0098 - accuracy: 0.0069 - val_loss: 0.0093 - val_accuracy: 0.0000e+00
# Epoch 4/100
# ...

# %%
plt.figure(figsize = (16, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train_loss', 'validation_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs Tembaga')
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_4/result_metal_4_loss.png')
plt.show()

# %%
plt.figure(figsize = (16, 8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy', 'validation_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.title('accuracy vs Epochs Tembaga')
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_4/result_metal_4_acc.png')
plt.show()

# %% [markdown]
# ## Prediksi

# %%
model = load_model('/content/drive/MyDrive/TransferLearning/Model_4/result_metal_4.h5')
pred = model.predict(X_test)

# %%
print(pred.shape)
# Out:
# (97, 1)

# %% [markdown]
# ## Plot the Prediction and Test value

# %%
plt.figure(figsize = (20,8))
plt.plot(y_test)
plt.plot(pred)
plt.xlabel('Periode')
plt.ylabel('Closing Prices')
plt.legend(['testing price','predicted price'])
plt.title('Perbandingan skala harga test dan prediksi close untuk Tembaga 97 Periode', fontsize = 15)
plt.savefig('/content/drive/MyDrive/TransferLearning/Model_4/result_metal_4_comparison_testingVSpredic_97_periode.png')

# %% [markdown]
# ## Performance Metrics

# %%
print('r2 score : ' + str(r2_score(y_test, pred)))
print('Mean Squared Error (MSE) : ' + str(mean_squared_error(y_test, pred)))
print('Root Mean Squared Error (RMSE) : ' + str(mean_squared_error(y_test, pred, squared=False)))
print('Mean Absolut Error (MAE) : ' + str(mean_absolute_error(y_test, pred)))
print('Mean Absolut Percentage Error (MAPE) : ' + str(mean_absolute_percentage_error(y_test, pred)))
# Out:
# r2 score : 0.9885391174333465
# Mean Squared Error (MSE) : 0.0008926074162435996
# Root Mean Squared Error (RMSE) : 0.029876536215625794
# Mean Absolut Error (MAE) : 0.020970171970245265
# Mean Absolut Percentage Error (MAPE) : 0.058375703918484574
